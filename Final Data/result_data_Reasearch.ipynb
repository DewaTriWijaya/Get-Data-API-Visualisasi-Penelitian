# %% [markdown]
# # 1.1 Clean Author

# %%
import pandas as pd

# Data Author
df_author = pd.read_csv('author.csv')

df_author.head()
# Out:
#                           author_id                   name  \
# 0  https://openalex.org/A5048632251  Eddy Suryanto Soegoto
# 1  https://openalex.org/A5052898875        Irawan Afrianto
# 2  https://openalex.org/A5077761860        Senny Luckyardi
# 3  https://openalex.org/A5030771199       Cherry Dharmawan
# 4  https://openalex.org/A5056478165        Taryana Suryana
#
#                                    orcid  institution  country  works_count  \
# 0                                    NaN          NaN      NaN            3
# 1  https://orcid.org/0000-0003-3245-6793          NaN      NaN           76
# 2  https://orcid.org/0000-0001-9954-7433          NaN      NaN           67
# 3  https://orcid.org/0000-0002-5221-8787          NaN      NaN           14
# 4                                    NaN          NaN      NaN           45
#
#    cited_by_count  h_index  i10_index
# 0               9        1          0
# 1             461       12         17
# ...

# %%
# hapus kolom author_id, orcid, institution, country
df_author = df_author.drop(columns=['author_id', 'orcid', 'institution', 'country'])

df_author.head()
# Out:
#                     name  works_count  cited_by_count  h_index  i10_index
# 0  Eddy Suryanto Soegoto            3               9        1          0
# 1        Irawan Afrianto           76             461       12         17
# 2        Senny Luckyardi           67             306       11         12
# 3       Cherry Dharmawan           14              20        3          0
# 4        Taryana Suryana           45              44        4          2

# %% [markdown]
# # 1.2 Clean Jurnal

# %% [markdown]
# ## 1.2.1 Clean cleaned_crossref_issn_multiple

# %%
df_crossref_issn = pd.read_csv('cleaned_crossref_issn_multiple.csv')

df_crossref_issn.head()
# Out:
#                              DOI  \
# 0  10.34010/komputika.v12i2.9763
# 1   10.34010/komputika.v9i1.2785
# 2   10.34010/komputika.v7i2.1511
# 3   10.34010/komputika.v6i2.1629
# 4  10.34010/komputika.v11i1.4350
#
#                                                Title  \
# 0  Aplikasi Probe Untuk Penilaian Capaian Pembela...
# 1  Prototype Sistem Monitoring Kesehatan Terinteg...
# 2  Perancangan E-Payment System pada E-Wallet Men...
# 3  Implementasi Julian Day dalam Penentuan Waktu ...
# 4  Analisis Komparasi Algoritma Klasifikasi Data ...
#
#                                              Authors  Author_Count  \
# 0  Usep Mohamad Ishaq; Mochamad Fajar Wicaksono; ...             3
# 1              Derisma Derisma; Moch. Harvie Saputra             2
# 2                        Agus Mulyana; Hanhan Wijaya             2
# 3                                      Sutono Sutono             1
# 4          Nabila Bianca Putri; Arie Wahyu Wijayanto             2
#
# ...

# %% [markdown]
# ## 1.2.2 Clean crossref_works

# %%
df_crossref_works = pd.read_csv('crossref_works.csv')

df_crossref_works.head()
# Out:
#         nidn                 author  \
# 0  410036002  EDDY SURYANTO SOEGOTO
# 1  410036002  EDDY SURYANTO SOEGOTO
# 2  410036002  EDDY SURYANTO SOEGOTO
# 3  410036002  EDDY SURYANTO SOEGOTO
# 4  410036002  EDDY SURYANTO SOEGOTO
#
#                                                title    year  \
# 0  Designing an Educational Website regarding Rec...  2021.0
# 1  STUDY PROGRAM PERFORMANCE IMPROVEMENT MODEL BY...  2017.0
# 2  Positioning Excellence – Based Model of Busine...  2016.0
# 3  ROLE OF IMAGE IN MARKETING PERFORMANCE ODEL SU...  2016.0
# 4  The Influence of Motivation on Quality Service...  2017.0
#
#                                              journal  citations
# 0  ASEAN Journal of Science and Engineering Educa...          3
# 1                              Majalah Ilmiah UNIKOM          0
# 2                        Jurnal Bisnis dan Manajemen          0
# 3                      Jurnal Keuangan dan Perbankan          0
# ...

# %% [markdown]
# ## 1.2.3 Clean index_penelitian

# %%
df_index_penelitian = pd.read_csv('index_penelitian.csv')
df_index_penelitian.head()
# Out:
#                           author_id  total_publications  total_citations  \
# 0  https://openalex.org/A5048632251                   3                9
# 1  https://openalex.org/A5052898875                  76              461
# 2  https://openalex.org/A5077761860                  67              306
# 3  https://openalex.org/A5030771199                  14               20
# 4  https://openalex.org/A5056478165                  45               44
#
#    h_index  i10_index  avg_citations
# 0        1          0           3.00
# 1       12         17           6.07
# 2       11         12           4.57
# 3        3          0           1.43
# 4        4          2           0.98

# %% [markdown]
# ## 1.2.4 Clean jurnal_penelitian

# %%
df_jurnal_penelitian = pd.read_csv('jurnal_penelitian.csv')
df_jurnal_penelitian.head()
# Out:
#                             work_id  \
# 0  https://openalex.org/W4210647064
# 1  https://openalex.org/W3215723935
# 2  https://openalex.org/W2784401774
# 3  https://openalex.org/W2210614275
# 4  https://openalex.org/W2756237186
#
#                                                title  year  journal  \
# 0  Designing an Educational Website regarding Rec...  2021      NaN
# 1  Kompetensi wirausaha dan gaya kepemimpinan ter...  2014      NaN
# 2                                Metode riset online  2014      NaN
# 3  PERBANDINGAN METODE JARINGAN SYARAF TIRUAN BAC...  2012      NaN
# 4  RANCANG BANGUN APLIKASI CHATBOT INFORMASI OBJE...  2015      NaN
#
#                                 publisher                 issn volume issue  \
# 0  Universitas Pendidikan Indonesia (UPI)  2775-6815;2775-6793      1     3
# 1                                     NaN                  NaN    NaN   NaN
# 2                                     NaN                  NaN    NaN   NaN
# ...

# %% [markdown]
# ##
